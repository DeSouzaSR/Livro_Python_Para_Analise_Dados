# %% [markdown]
# # Gráficos inline
#
# Teste de plotagem de gráficos inline no Jupyter Notebook. Reprodução da Figura 2.6

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())
